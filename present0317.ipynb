# %%
# %reload_ext autoreload
# %autoreload 2
from display import *
import warnings
warnings.filterwarnings('ignore')
action_name_s = ["keymove", 'jump', 'costopall', 'wrap', 'cochangescore', 'movetomouse', 'moveanimate']

# %% [markdown]
# left to right: recall, f1, auc

# %%
for action_name in action_name_s:
    print(action_name)
    plot(action_name)
# Out:
# keymove
# jump
# costopall
# wrap
# cochangescore
# movetomouse
# moveanimate
