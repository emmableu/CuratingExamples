# %%
import pandas as pd
# %reload_ext autoreload
# %autoreload 2
pd.options.display.max_rows = 2000
pd.set_option('display.max_colwidth', -1)
game_label_names = ['keymove', 'jump', 'costopall', 'wrap',  'cochangescore', 'movetomouse', 'moveanimate']
game_label_names = ['keymove', 'jump', 'cochangescore', 'movetomouse', 'moveanimate']

def print_label_feature(game_label):
#     game_label = "jump"
    file_dir = "/Users/wwang33/Documents/SnapHints/data/csc110/fall2019project1/submitted/"
                           
    feature = pd.read_csv(file_dir +  game_label + "/cv/fold0/SnapHintsTrainTest/features.csv").sort_values(by = ["zScore", "snapshotCountA"], ascending = False)
    return feature

# %% [markdown]
# #### Problem with movetomouse: there's another kind of move with mouse, using reportMouseX, that's not here.

# %%
print_label_feature("movetomouse")
# Out:
#                                                                       name  \
# 0   0.73: [{literal:mouse-pointer}, *]
# 1   0.73: [{literal:mouse-pointer}, *, *]
# 2   0.73: [{literal:mouse-pointer}, *, *, *]
# 3   0.73: [{literal:mouse-pointer}, *, *, *, *]
# 4   0.65: [snapshot, stage:Stage, {sprite:userDef}, *, script, *]
# 5   0.65: [snapshot, stage:Stage, {sprite:userDef}, *, *, script, *]
# 6   0.65: [snapshot, stage:Stage, {sprite:userDef}, *, script, *, *]
# 7   0.65: [stage:Stage, {sprite:userDef}, *, script, *]
# 8   0.65: [stage:Stage, {sprite:userDef}, *, script, *, *]
# 9   0.65: [stage:Stage, {sprite:userDef}, *, *, script, *]
# 10  0.65: [{sprite:userDef}, *, script, *]
# 11  0.65: [{sprite:userDef}, *, *, script, *]
# 12  0.65: [{sprite:userDef}, *, script, *, *]
# 19  0.60: [script, {setHeading}, *, literal:userDef]
# 20  0.60: [script, {setHeading}, *, *, literal:userDef]
# 21  0.60: [script, {setHeading}, *, literal:userDef, *]
# 22  0.60: [script, {setHeading}, *, *, *, literal:userDef]
# 23  0.60: [script, {setHeading}, *, *, literal:userDef, *]
# 24  0.60: [script, {setHeading}, *, literal:userDef, *, *]
# 25  0.60: [{setHeading}, *, literal:userDef]
# 27  0.60: [{setHeading}, *, literal:userDef, *]
# 28  0.60: [{setHeading}, *, *, literal:userDef]
# 30  0.60: [{setHeading}, *, *, *, literal:userDef]
# 31  0.60: [{setHeading}, *, literal:userDef, *, *]
# 32  0.60: [{setHeading}, *, *, literal:userDef, *]
# 34  0.60: [stage:Stage, sprite:userDef, {script}, setHeading]
# 38  0.60: [script, {setHeading}, literal:userDef]
# 39  0.60: [sprite:userDef, {script}, setHeading]
# 40  0.60: [script, {setHeading}, literal:userDef, *]
# 41  0.60: [script, {setHeading}, literal:userDef, *, *]
# 42  0.60: [script, {setHeading}, literal:userDef, *, *, *]
# 43  0.60: [{setHeading}, literal:userDef]
# 44  0.60: [{setHeading}, literal:userDef, *]
# 45  0.60: [{setHeading}, literal:userDef, *, *]
# 46  0.60: [{setHeading}, literal:userDef, *, *, *]
# 13  0.58: [sprite:userDef, script, {setHeading}, *, literal:userDef]
# 14  0.58: [sprite:userDef, script, {setHeading}, *, *, literal:userDef]
# 15  0.58: [sprite:userDef, script, {setHeading}, *, literal:userDef, *]
# 16  0.58: [sprite:userDef, script, {setHeading}, *, literal:userDef, *, *]
# 17  0.58: [sprite:userDef, script, {setHeading}, *, *, *, literal:userDef]
# 18  0.58: [sprite:userDef, script, {setHeading}, *, *, literal:userDef, *]
# 33  0.58: [sprite:userDef, script, {setHeading}, literal:userDef]
# 35  0.58: [sprite:userDef, script, {setHeading}, literal:userDef, *]
# 36  0.58: [sprite:userDef, script, {setHeading}, literal:userDef, *, *]
# 37  0.58: [sprite:userDef, script, {setHeading}, literal:userDef, *, *, *]
# 26  0.55: [{script}, doIf, doIf, *]
# 29  0.55: [{script}, doIf, doIf, *, *]
#
#     id  supportA  supportB  snapshotCountA  snapshotCountB    zScore
# 0   0   0.725     0.25228   29              83              6.140021
# 1   1   0.725     0.25228   29              83              6.140021
# 2   2   0.725     0.25228   29              83              6.140021
# 3   3   0.725     0.25228   29              83              6.140021
# 4   4   0.650     0.00000   26              0              -1.000000
# 5   5   0.650     0.00000   26              0              -1.000000
# 6   6   0.650     0.00000   26              0              -1.000000
# 7   7   0.650     0.00000   26              0              -1.000000
# 8   8   0.650     0.00000   26              0              -1.000000
# 9   9   0.650     0.00000   26              0              -1.000000
# 10  10  0.650     0.00000   26              0              -1.000000
# 11  11  0.650     0.00000   26              0              -1.000000
# 12  12  0.650     0.00000   26              0              -1.000000
# 19  19  0.600     0.00000   24              0              -1.000000
# 20  20  0.600     0.00000   24              0              -1.000000
# 21  21  0.600     0.00000   24              0              -1.000000
# 22  22  0.600     0.00000   24              0              -1.000000
# 23  23  0.600     0.00000   24              0              -1.000000
# 24  24  0.600     0.00000   24              0              -1.000000
# 25  25  0.600     0.00000   24              0              -1.000000
# 27  27  0.600     0.00000   24              0              -1.000000
# 28  28  0.600     0.00000   24              0              -1.000000
# 30  30  0.600     0.00000   24              0              -1.000000
# 31  31  0.600     0.00000   24              0              -1.000000
# 32  32  0.600     0.00000   24              0              -1.000000
# 34  34  0.600     0.00000   24              0              -1.000000
# 38  38  0.600     0.00000   24              0              -1.000000
# 39  39  0.600     0.00000   24              0              -1.000000
# 40  40  0.600     0.00000   24              0              -1.000000
# 41  41  0.600     0.00000   24              0              -1.000000
# 42  42  0.600     0.00000   24              0              -1.000000
# 43  43  0.600     0.00000   24              0              -1.000000
# 44  44  0.600     0.00000   24              0              -1.000000
# 45  45  0.600     0.00000   24              0              -1.000000
# 46  46  0.600     0.00000   24              0              -1.000000
# 13  13  0.575     0.00000   23              0              -1.000000
# 14  14  0.575     0.00000   23              0              -1.000000
# 15  15  0.575     0.00000   23              0              -1.000000
# 16  16  0.575     0.00000   23              0              -1.000000
# 17  17  0.575     0.00000   23              0              -1.000000
# 18  18  0.575     0.00000   23              0              -1.000000
# 33  33  0.575     0.00000   23              0              -1.000000
# 35  35  0.575     0.00000   23              0              -1.000000
# 36  36  0.575     0.00000   23              0              -1.000000
# 37  37  0.575     0.00000   23              0              -1.000000
# 26  26  0.550     0.00000   22              0              -1.000000
# 29  29  0.550     0.00000   22              0              -1.000000

# %% [markdown]
# #### Problem with cochangescore: need an AND to concatenate two rules

# %%
print_label_feature("cochangescore")
# Out:
#                                                                          name  \
# 36   0.91: [reportTouchingObject, {literal:userDef}, *]
# 37   0.91: [reportTouchingObject, {literal:userDef}, *, *]
# 38   0.91: [reportTouchingObject, {literal:userDef}, *, *, *]
# 39   0.91: [reportTouchingObject, {literal:userDef}, *, *, *, *]
# 46   0.82: [doIf, reportTouchingObject, {literal:userDef}, *]
# 47   0.82: [doIf, reportTouchingObject, {literal:userDef}, *, *]
# 48   0.82: [doIf, reportTouchingObject, {literal:userDef}, *, *, *]
# 49   0.82: [doIf, reportTouchingObject, {literal:userDef}, *, *, *, *]
# 5    0.99: [script, doChangeVar, {varMenu:userDef}, *]
# 8    0.99: [script, doChangeVar, {varMenu:userDef}, *, *]
# 10   0.99: [script, doChangeVar, {varMenu:userDef}, *, *, *]
# 13   0.99: [script, doChangeVar, {varMenu:userDef}, *, *, *, *]
# 16   0.99: [doChangeVar, {varMenu:userDef}, *]
# 20   0.99: [doChangeVar, {varMenu:userDef}, *, *]
# 23   0.99: [doChangeVar, {varMenu:userDef}, *, *, *]
# 25   0.99: [doChangeVar, {varMenu:userDef}, *, *, *, *]
# 28   0.97: [script, doChangeVar, {literal:userDef}, *]
# 29   0.97: [script, doChangeVar, {literal:userDef}, *, *]
# 30   0.97: [script, doChangeVar, {literal:userDef}, *, *, *]
# 31   0.97: [script, doChangeVar, {literal:userDef}, *, *, *, *]
# 32   0.97: [doChangeVar, {literal:userDef}, *]
# 33   0.97: [doChangeVar, {literal:userDef}, *, *]
# 34   0.97: [doChangeVar, {literal:userDef}, *, *, *]
# 35   0.97: [doChangeVar, {literal:userDef}, *, *, *, *]
# 6    0.99: [script, doSetVar, {literal:userDef}, *]
# 9    0.99: [script, doSetVar, {literal:userDef}, *, *]
# 12   0.99: [script, doSetVar, {literal:userDef}, *, *, *]
# 15   0.99: [script, doSetVar, {literal:userDef}, *, *, *, *]
# 18   0.99: [doSetVar, {literal:userDef}, *]
# 21   0.99: [doSetVar, {literal:userDef}, *, *]
# 24   0.99: [doSetVar, {literal:userDef}, *, *, *]
# 27   0.99: [doSetVar, {literal:userDef}, *, *, *, *]
# 0    1.00: [{varMenu:userDef}, *]
# 1    1.00: [{varMenu:userDef}, *, *]
# 2    1.00: [{varMenu:userDef}, *, *, *]
# 3    1.00: [{varMenu:userDef}, *, *, *, *]
# 4    0.99: [script, doSetVar, {varMenu:userDef}, *]
# 7    0.99: [script, doSetVar, {varMenu:userDef}, *, *]
# 11   0.99: [script, doSetVar, {varMenu:userDef}, *, *, *]
# 14   0.99: [script, doSetVar, {varMenu:userDef}, *, *, *, *]
# 17   0.99: [doSetVar, {varMenu:userDef}, *]
# 19   0.99: [doSetVar, {varMenu:userDef}, *, *]
# 22   0.99: [doSetVar, {varMenu:userDef}, *, *, *]
# 26   0.99: [doSetVar, {varMenu:userDef}, *, *, *, *]
# 70   0.64: [script, forward, {literal:userDef}, *]
# 71   0.64: [script, forward, {literal:userDef}, *, *]
# 72   0.64: [script, forward, {literal:userDef}, *, *, *]
# 73   0.64: [script, forward, {literal:userDef}, *, *, *, *]
# 74   0.64: [forward, {literal:userDef}, *]
# 75   0.64: [forward, {literal:userDef}, *, *]
# 76   0.64: [forward, {literal:userDef}, *, *, *]
# 77   0.64: [forward, {literal:userDef}, *, *, *, *]
# 40   0.87: [{snapshot}, varDec:userDef, varDec:userDef, *]
# 41   0.87: [{snapshot}, varDec:userDef, varDec:userDef, *, *]
# 42   0.87: [*, {snapshot}, varDec:userDef, varDec:userDef, *]
# 43   0.87: [*, *, {snapshot}, varDec:userDef, varDec:userDef, *]
# 44   0.87: [*, {snapshot}, varDec:userDef, varDec:userDef, *, *]
# 45   0.87: [*, *, {snapshot}, varDec:userDef, varDec:userDef, *, *]
# 54   0.67: [doIf, reportEquals, {literal:userDef}, *]
# 55   0.67: [doIf, reportEquals, {literal:userDef}, *, *]
# 56   0.67: [doIf, reportEquals, {literal:userDef}, *, *, *]
# 57   0.67: [doIf, reportEquals, {literal:userDef}, *, *, *, *]
# 98   0.52: [{snapshot}, *, stage:Stage, varDec:userDef, varDec:userDef]
# 99   0.52: [*, {snapshot}, *, stage:Stage, varDec:userDef, varDec:userDef]
# 100  0.52: [*, *, {snapshot}, *, stage:Stage, varDec:userDef, varDec:userDef]
# 101  0.52: [{snapshot}, stage:Stage, varDec:userDef, varDec:userDef]
# 102  0.52: [*, {snapshot}, stage:Stage, varDec:userDef, varDec:userDef]
# 103  0.52: [*, *, {snapshot}, stage:Stage, varDec:userDef, varDec:userDef]
# 50   0.81: [{var:userDef}, *]
# 51   0.81: [{var:userDef}, *, *]
# 52   0.81: [{var:userDef}, *, *, *]
# 53   0.81: [{var:userDef}, *, *, *, *]
# 84   0.58: [reportKeyPressed, {literal:left arrow}, *]
# 87   0.58: [reportKeyPressed, {literal:left arrow}, *, *]
# 90   0.58: [reportKeyPressed, {literal:left arrow}, *, *, *]
# 93   0.58: [reportKeyPressed, {literal:left arrow}, *, *, *, *]
# 58   0.67: [reportEquals, {var:userDef}, *]
# 59   0.67: [reportEquals, {var:userDef}, *, *]
# 60   0.67: [reportEquals, {var:userDef}, *, *, *]
# 61   0.67: [reportEquals, {var:userDef}, *, *, *, *]
# 104  0.51: [{literal:all}, *]
# 105  0.51: [{literal:all}, *, *]
# 106  0.51: [{literal:all}, *, *, *]
# 107  0.51: [{literal:all}, *, *, *, *]
# 83   0.58: [reportKeyPressed, {literal:right arrow}, *]
# 86   0.58: [reportKeyPressed, {literal:right arrow}, *, *]
# 89   0.58: [reportKeyPressed, {literal:right arrow}, *, *, *]
# 92   0.58: [reportKeyPressed, {literal:right arrow}, *, *, *, *]
# 94   0.57: [doIf, reportEquals, {var:userDef}, *]
# 95   0.57: [doIf, reportEquals, {var:userDef}, *, *]
# 96   0.57: [doIf, reportEquals, {var:userDef}, *, *, *]
# 97   0.57: [doIf, reportEquals, {var:userDef}, *, *, *, *]
# 78   0.58: [script, changeXPosition, {literal:userDef}, *]
# 79   0.58: [script, changeXPosition, {literal:userDef}, *, *]
# 80   0.58: [script, changeXPosition, {literal:userDef}, *, *, *]
# 81   0.58: [script, changeXPosition, {literal:userDef}, *, *, *, *]
# 82   0.58: [changeXPosition, {literal:userDef}, *]
# 85   0.58: [changeXPosition, {literal:userDef}, *, *]
# 88   0.58: [changeXPosition, {literal:userDef}, *, *, *]
# 91   0.58: [changeXPosition, {literal:userDef}, *, *, *, *]
# 62   0.66: [reportRandom, {literal:userDef}, *]
# 63   0.66: [reportRandom, {literal:userDef}, *, *]
# 64   0.66: [reportRandom, {literal:userDef}, *, *, *]
# 65   0.66: [reportRandom, {literal:userDef}, *, *, *, *]
# 66   0.66: [{literal:left arrow}, *]
# 67   0.66: [{literal:left arrow}, *, *]
# 68   0.66: [{literal:left arrow}, *, *, *]
# 69   0.66: [{literal:left arrow}, *, *, *, *]
#
#       id  supportA  supportB  snapshotCountA  snapshotCountB    zScore
# 36   36   0.910891  0.432836  92              116             8.256097
# 37   37   0.910891  0.432836  92              116             8.256097
# 38   38   0.910891  0.432836  92              116             8.256097
# 39   39   0.910891  0.432836  92              116             8.256097
# 46   46   0.821782  0.343284  83              92              8.207333
# 47   47   0.821782  0.343284  83              92              8.207333
# 48   48   0.821782  0.343284  83              92              8.207333
# 49   49   0.821782  0.343284  83              92              8.207333
# 5    5    0.990099  0.589552  100             158             7.480371
# 8    8    0.990099  0.589552  100             158             7.480371
# 10   10   0.990099  0.589552  100             158             7.480371
# 13   13   0.990099  0.589552  100             158             7.480371
# 16   16   0.990099  0.589552  100             158             7.480371
# 20   20   0.990099  0.589552  100             158             7.480371
# 23   23   0.990099  0.589552  100             158             7.480371
# 25   25   0.990099  0.589552  100             158             7.480371
# 28   28   0.970297  0.582090  98              156             7.178594
# 29   29   0.970297  0.582090  98              156             7.178594
# 30   30   0.970297  0.582090  98              156             7.178594
# 31   31   0.970297  0.582090  98              156             7.178594
# 32   32   0.970297  0.582090  98              156             7.178594
# 33   33   0.970297  0.582090  98              156             7.178594
# 34   34   0.970297  0.582090  98              156             7.178594
# 35   35   0.970297  0.582090  98              156             7.178594
# 6    6    0.990099  0.619403  100             166             7.077824
# 9    9    0.990099  0.619403  100             166             7.077824
# 12   12   0.990099  0.619403  100             166             7.077824
# 15   15   0.990099  0.619403  100             166             7.077824
# 18   18   0.990099  0.619403  100             166             7.077824
# 21   21   0.990099  0.619403  100             166             7.077824
# 24   24   0.990099  0.619403  100             166             7.077824
# 27   27   0.990099  0.619403  100             166             7.077824
# 0    0    1.000000  0.641791  101             172             6.992956
# 1    1    1.000000  0.641791  101             172             6.992956
# 2    2    1.000000  0.641791  101             172             6.992956
# 3    3    1.000000  0.641791  101             172             6.992956
# 4    4    0.990099  0.626866  100             168             6.977485
# 7    7    0.990099  0.626866  100             168             6.977485
# 11   11   0.990099  0.626866  100             168             6.977485
# 14   14   0.990099  0.626866  100             168             6.977485
# 17   17   0.990099  0.626866  100             168             6.977485
# 19   19   0.990099  0.626866  100             168             6.977485
# 22   22   0.990099  0.626866  100             168             6.977485
# 26   26   0.990099  0.626866  100             168             6.977485
# 70   70   0.643564  0.272388  65              73              6.570160
# 71   71   0.643564  0.272388  65              73              6.570160
# 72   72   0.643564  0.272388  65              73              6.570160
# 73   73   0.643564  0.272388  65              73              6.570160
# 74   74   0.643564  0.272388  65              73              6.570160
# 75   75   0.643564  0.272388  65              73              6.570160
# 76   76   0.643564  0.272388  65              73              6.570160
# 77   77   0.643564  0.272388  65              73              6.570160
# 40   40   0.871287  0.589552  88              158             5.118725
# 41   41   0.871287  0.589552  88              158             5.118725
# 42   42   0.871287  0.589552  88              158             5.118725
# 43   43   0.871287  0.589552  88              158             5.118725
# 44   44   0.871287  0.589552  88              158             5.118725
# 45   45   0.871287  0.589552  88              158             5.118725
# 54   54   0.673267  0.399254  68              107             4.699953
# 55   55   0.673267  0.399254  68              107             4.699953
# 56   56   0.673267  0.399254  68              107             4.699953
# 57   57   0.673267  0.399254  68              107             4.699953
# 98   98   0.524752  0.279851  53              75              4.406762
# 99   99   0.524752  0.279851  53              75              4.406762
# 100  100  0.524752  0.279851  53              75              4.406762
# 101  101  0.524752  0.279851  53              75              4.406762
# 102  102  0.524752  0.279851  53              75              4.406762
# 103  103  0.524752  0.279851  53              75              4.406762
# 50   50   0.811881  0.567164  82              152             4.351416
# 51   51   0.811881  0.567164  82              152             4.351416
# 52   52   0.811881  0.567164  82              152             4.351416
# 53   53   0.811881  0.567164  82              152             4.351416
# 84   84   0.584158  0.335821  59              90              4.334900
# 87   87   0.584158  0.335821  59              90              4.334900
# 90   90   0.584158  0.335821  59              90              4.334900
# 93   93   0.584158  0.335821  59              90              4.334900
# 58   58   0.673267  0.425373  68              114             4.246696
# 59   59   0.673267  0.425373  68              114             4.246696
# 60   60   0.673267  0.425373  68              114             4.246696
# 61   61   0.673267  0.425373  68              114             4.246696
# 104  104  0.514851  0.279851  52              75              4.236439
# 105  105  0.514851  0.279851  52              75              4.236439
# 106  106  0.514851  0.279851  52              75              4.236439
# 107  107  0.514851  0.279851  52              75              4.236439
# 83   83   0.584158  0.343284  59              92              4.195812
# 86   86   0.584158  0.343284  59              92              4.195812
# 89   89   0.584158  0.343284  59              92              4.195812
# 92   92   0.584158  0.343284  59              92              4.195812
# 94   94   0.574257  0.339552  58              91              4.096939
# 95   95   0.574257  0.339552  58              91              4.096939
# 96   96   0.574257  0.339552  58              91              4.096939
# 97   97   0.574257  0.339552  58              91              4.096939
# 78   78   0.584158  0.354478  59              95              3.989205
# 79   79   0.584158  0.354478  59              95              3.989205
# 80   80   0.584158  0.354478  59              95              3.989205
# 81   81   0.584158  0.354478  59              95              3.989205
# 82   82   0.584158  0.354478  59              95              3.989205
# 85   85   0.584158  0.354478  59              95              3.989205
# 88   88   0.584158  0.354478  59              95              3.989205
# 91   91   0.584158  0.354478  59              95              3.989205
# 62   62   0.663366  0.432836  67              116             3.949005
# 63   63   0.663366  0.432836  67              116             3.949005
# 64   64   0.663366  0.432836  67              116             3.949005
# 65   65   0.663366  0.432836  67              116             3.949005
# 66   66   0.663366  0.436567  67              117             3.884973
# 67   67   0.663366  0.436567  67              117             3.884973
# 68   68   0.663366  0.436567  67              117             3.884973
# 69   69   0.663366  0.436567  67              117             3.884973
