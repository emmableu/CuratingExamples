# %%
import pandas as pd
# %reload_ext autoreload
# %autoreload 2
pd.options.display.max_rows = 2000
pd.set_option('display.max_colwidth', -1)
game_label_names = ['keymove', 'jump', 'costopall', 'wrap',  'cochangescore', 'movetomouse', 'moveanimate']
def print_label(game_label):
#     game_label = "jump"
    file_dir = "/Users/wwang33/Documents/SnapHints/data/csc110/fall2019project1/submitted/"
    feature = pd.read_csv(file_dir + game_label + "/feature_extraction_output/features.csv").sort_values(by = ["zScore"], ascending = False)
    return feature

def print_label_remove_duplicates(game_label):
#     game_label = "jump"
    file_dir = "/Users/wwang33/Documents/SnapHints/data/csc110/fall2019project1/submitted/"
    feature = pd.read_csv(file_dir + game_label + "/feature_extraction_output_remove_duplicates/features.csv").sort_values(by = ["zScore"], ascending = False)
    return feature

# %% [markdown]
# #### Question: how to use a AND operator?

# %%
print_label_remove_duplicates("costopall")
# figure out why stopall is not here. 
# ratios are inconsistent
# Out:
#                                                                          name  \
# 1    0.77: [doIf, reportTouchingObject, {literal:userDef}, *, *, *, *]
# 0    0.82: [reportTouchingObject, {literal:userDef}, *, *, *, *]
# 2    0.64: [forward, {literal:userDef}, *, *, *, *]
# 86   0.27: [{sprite:userDef}, *, *, *, varDec:userDef]
# 84   0.23: [{script}, receiveGo, doSwitchToCostume, *, *]
# 83   0.18: [{script}, hide, doStopThis, *, *]
# 82   0.23: [{script}, gotoXY, doForever, *, *]
# 81   0.14: [{script}, doWait, doChangeVar, *, *]
# 80   0.14: [{script}, receiveGo, playSound, *, *]
# 79   0.14: [{script}, hide, doTellTo, *, *]
# 78   0.23: [{script}, gotoXY, doSwitchToCostume]
# 77   0.14: [{script}, doWait, gotoXY]
# 76   0.14: [{script}, doSetVar, setScale]
# 75   0.14: [{script}, setScale, gotoXY]
# 74   0.23: [{script}, doSwitchToCostume, doSetVar]
# 73   0.14: [{script}, receiveGo, doTellTo]
# 72   0.14: [{script}, receiveInteraction, hide]
# ...

# %%
print_label("costopall")
# Out:
#                                                                                                          name  \
# 13    0.95: [doStopThis, {literal:all}, *, *, *]
# 3     0.95: [script, doStopThis, {literal:all}, *, *]
# 1     0.95: [script, doStopThis, {literal:all}, *]
# 5     0.95: [script, doStopThis, {literal:all}, *, *, *]
# 7     0.95: [script, doStopThis, {literal:all}, *, *, *, *]
# 9     0.95: [doStopThis, {literal:all}, *]
# 15    0.95: [doStopThis, {literal:all}, *, *, *, *]
# 11    0.95: [doStopThis, {literal:all}, *, *]
# 19    0.95: [{literal:all}, *, *, *, *]
# 18    0.95: [{literal:all}, *, *, *]
# 17    0.95: [{literal:all}, *, *]
# 16    0.95: [{literal:all}, *]
# 26    0.77: [doIf, reportTouchingObject, {literal:userDef}, *, *, *]
# 25    0.77: [doIf, reportTouchingObject, {literal:userDef}, *, *]
# 27    0.77: [doIf, reportTouchingObject, {literal:userDef}, *, *, *, *]
# 24    0.77: [doIf, reportTouchingObject, {literal:userDef}, *]
# ...
