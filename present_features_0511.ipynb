# %%
import pandas as pd
# %reload_ext autoreload
# %autoreload 2
pd.options.display.max_rows = 2000
pd.set_option('display.max_colwidth', -1)
game_label_names = ['keymove', 'jump', 'costopall', 'wrap',  'cochangescore', 'movetomouse', 'moveanimate']
game_label_names = ['keymove', 'jump', 'cochangescore', 'movetomouse', 'moveanimate']

def print_label_feature(game_label):
#     game_label = "jump"
    file_dir = "/Users/wwang33/Documents/SnapHints/data/csc110/fall2019project1/submitted/"
                           
#     feature = pd.read_csv(file_dir +  game_label + "/cv/fold0/SnapHintsAndAll/features.csv").sort_values(by = ["supportA"], ascending = False)
    feature = pd.read_csv(file_dir +  game_label + "/cv/fold0/SnapHintsAndAll/features.csv")

    return feature

# %% [markdown]
# #### Problem with movetomouse: there's another kind of move with mouse, using reportMouseX, that's not here.

# %% [markdown]
# #### Problem with cochangescore: need an AND to concatenate two rules

# %%
print_label_feature("movetomouse")
# Out:
#                                                                                                                                                                                    name  \
# 0    0.45:\t0.73: [{literal:mouse-pointer}, *] AND\n\t\t\t\t0.65: [stage:Stage, {sprite:userDef}, *, script, *]
# 1    0.45:\t0.73: [{literal:mouse-pointer}, *] AND\n\t\t\t\t0.60: [script, {setHeading}, *, literal:userDef, *]
# 2    0.48:\t0.73: [{literal:mouse-pointer}, *] AND\n\t\t\t\t0.55: [{script}, doIf, doIf, *]
# 3    0.33:\t0.73: [{literal:mouse-pointer}, *] AND\n\t\t\t\t0.48: [{script}, turn]
# 4    0.28:\t0.73: [{literal:mouse-pointer}, *] AND\n\t\t\t\t0.43: [script, doForever, {script}, *, forward]
# 5    0.30:\t0.73: [{literal:mouse-pointer}, *] AND\n\t\t\t\t0.33: [script, doForever, {script}, *, doPlaySoundUntilDone]
# 6    0.28:\t0.73: [{literal:mouse-pointer}, *] AND\n\t\t\t\t0.28: [script, {changeEffect}, *, literal:color]
# ...
