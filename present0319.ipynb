# %%
# %reload_ext autoreload
# %autoreload 2
# from display import *
import warnings
warnings.filterwarnings('ignore')
action_name_s = ["keymove", 'jump', 'costopall', 'wrap', 'cochangescore', 'movetomouse', 'moveanimate']

# %% [markdown]
# #### Compare using and not using model selection

# %%
from display_al_0319 import *
plot_all()

# %% [markdown]
# ####

# %%
from display_al import *
plot_all()
# Out:
# keymove
# cochangescore
# jump
# movetomouse
# moveanimate
# costopall
# wrap

# %% [markdown]
# #### Using model selection and one-hot features

# %%
from display_al import *
plot_all()

# %% [markdown]
# #### Not using model selection and using one-hot features

# %%
from display_al import *
plot_all()
