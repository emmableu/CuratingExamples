# %%
# %reload_ext autoreload
# %autoreload 2
from display import *
import warnings
warnings.filterwarnings('ignore')

# %%
action_name_s = [ 'jump', 'costopall', 'wrap', 'cochangescore', 'movetomouse', 'moveanimate']
for action_name in action_name_s:
    print(action_name)
    plot(action_name)
# Out:
# jump
# costopall
# wrap
# cochangescore
# movetomouse
# moveanimate
